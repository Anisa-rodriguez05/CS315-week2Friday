# %% [markdown]
# # Scrapers for MyDramaList
#
# You will follow the instructions in Part 4 of Week 2 Tasks. In the top part of the notebook summarize through a table of content what you decided to do and then explain why.

# %%
import requests
import csv
from bs4 import BeautifulSoup

# %%
url = "https://mydramalist.com/shows/newest"

Dramas = []

numPages = 2 

for page in range (1, numPages + 1):
    page_url = f"{url}?page{page}"
    response = requests.get(page_url)
    soup = BeautifulSoup(response.content, "html.parser")

    cards = soup.find_all("div", class_="box")

    for card in cards:
        rating = card.find("span", class_="score").get_text(strip=True)
        title = card.find("h6").get_text(strip=True)
        info = card.find("span", class_text="info").get_text(strip=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       7 for page in range (1, numPages + 1):
#       8     page_url = f"{url}?page{page}"
# ----> 9     response = requests.get(page_url)
#      10     soup = BeautifulSoup(response.content, "html.parser")
#      12     cards = soup.find_all("div", class_="box")
#
# NameError: name 'requests' is not defined
